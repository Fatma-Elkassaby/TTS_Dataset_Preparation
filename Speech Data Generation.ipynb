# %%
import os                       
import torch                    
from pydub import AudioSegment, silence
from pyannote.audio import Pipeline  
import torchaudio
from dotenv import load_dotenv
import csv
from pathlib import Path
from pydub.silence import detect_silence
from tenacity import retry, stop_after_attempt, wait_exponential
from tqdm import tqdm
import google.generativeai as genai
import pandas as pd
import time
from pyannote.audio import Inference
import numpy as np
import whisper
# Out:
# C:\Users\laila\.conda\envs\pyannote310_env\lib\site-packages\pyannote\audio\core\io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# C:\Users\laila\.conda\envs\pyannote310_env\lib\site-packages\google\api_core\_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.11) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# C:\Users\laila\AppData\Local\Temp\ipykernel_33100\1416914138.py:12: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
MIN_LEN = 5000
MAX_LEN = 8000
MIN_SILENCE_LEN = 600  
SILENCE_THRESH = -35 
max_extra_percent=0.15
PADDING_MS = 200

# %%
load_dotenv()
HF_TOKEN = os.getenv("HF_TOKEN")
pipeline = Pipeline.from_pretrained(
    "pyannote/speaker-diarization-3.1",
    use_auth_token=HF_TOKEN
)
# Out:
# C:\Users\laila\.conda\envs\pyannote310_env\lib\site-packages\pyannote\audio\pipelines\speaker_verification.py:43: UserWarning: torchaudio._backend.get_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   backend = torchaudio.get_audio_backend()
# C:\Users\laila\.conda\envs\pyannote310_env\lib\site-packages\pyannote\audio\pipelines\speaker_verification.py:45: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   from speechbrain.pretrained import (
# C:\Users\laila\.conda\envs\pyannote310_env\lib\site-packages\pyannote\audio\pipelines\speaker_verification.py:53: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend(backend)
# C:\Users\laila\.conda\envs\pyannote310_env\lib\site-packages\pyannote\audio\tasks\segmentation\mixins.py:37: UserWarning: `torchaudio.backend.common.AudioMetaData` has been moved to `torchaudio.AudioMetaData`. Please update the import path.
#   from torchaudio.backend.common import AudioMetaData
# C:\Users\laila\.conda\envs\pyannote310_env\lib\site-packages\lightning_fabric\utilities\cloud_io.py:73: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.

# %%
api_key = os.getenv("GEMINI_API_KEY")

if not api_key:
    raise EnvironmentError(
        "GEMINI_API_KEY not found. Please set it as an environment variable."
    )
genai.configure(api_key=api_key)
model = genai.GenerativeModel("models/gemini-2.5-flash")
print(" AudioTranscriber initialized successfully.")
# Out:
#  AudioTranscriber initialized successfully.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
whisper_model = whisper.load_model("medium", device=device)

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
embedding_model = Inference(
    "pyannote/embedding", 
    device=device,
    use_auth_token=HF_TOKEN
)
speaker_embeddings_db = {}
# Out:
# C:\Users\laila\.conda\envs\pyannote310_env\lib\site-packages\pytorch_lightning\utilities\migration\migration.py:208: You have multiple `ModelCheckpoint` callback states in this checkpoint, but we found state keys that would end up colliding with each other after an upgrade, which means we can't differentiate which of your checkpoint callbacks needs which states. At least one of your `ModelCheckpoint` callbacks will not be able to reload the state.
# Lightning automatically upgraded your loaded checkpoint from v1.2.7 to v2.6.0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint C:\Users\laila\.cache\torch\pyannote\models--pyannote--embedding\snapshots\4db4899737a38b2d618bbd74350915aa10293cb2\pytorch_model.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.8.1+cu102, yours is 2.5.1+cu121. Bad things might happen unless you revert torch to 1.x.
# C:\Users\laila\.conda\envs\pyannote310_env\lib\site-packages\pytorch_lightning\core\saving.py:197: Found keys that are not in the model state dict but in the checkpoint: ['loss_func.W']

# %%
# def split_audio_fixed_length(filepath, chunk_minutes=2, out_dir="Final_Output"):
#     podcast_name = Path(filepath).stem 
#     podcast_dir = os.path.join(out_dir, podcast_name)
#     os.makedirs(podcast_dir, exist_ok=True)
#     audio = AudioSegment.from_wav(filepath)
#     chunk_length = chunk_minutes * 60 * 1000
#     chunk_files = []
#     start_ms = 0
#     chunk_idx = 1
#     while start_ms < len(audio):
#         end_ms = min(start_ms + chunk_length, len(audio))
#         silences = detect_silence(
#             audio[start_ms:end_ms],
#             min_silence_len=MIN_SILENCE_LEN,
#             silence_thresh=SILENCE_THRESH
#         )
#         if silences:
#             last_silence_end = silences[-1][1]
#             end_ms = start_ms + last_silence_end
#         chunk = audio[start_ms:end_ms]
#         chunk_name = f"chunk{chunk_idx:02d}.wav"
#         chunk_path = os.path.join(podcast_dir, chunk_name)
#         chunk.export(chunk_path, format="wav")
#         chunk_files.append(chunk_path)
#         print(f" Saved chunk: {chunk_path}")
#         start_ms = end_ms
#         chunk_idx += 1
#     return chunk_files

# %%
def split_segment(segment_audio, min_len=MIN_LEN, max_len=MAX_LEN):
    segments = []
    audio_len = len(segment_audio)
    start = 0
    while start < audio_len:
        search_end = min(start + max_len, audio_len)
        segment = segment_audio[start:search_end]
        silences = silence.detect_silence(
            segment,
            min_silence_len=MIN_SILENCE_LEN,
            silence_thresh=SILENCE_THRESH
        )
        if silences:
            cut = start + silences[-1][1]
        else:
            extra_allowed = int(max_len * 0.2)
            search_end_extra = min(start + max_len + extra_allowed, audio_len)
            segment_extra = segment_audio[start:search_end_extra]
            silences_extra = silence.detect_silence(
                segment_extra,
                min_silence_len=MIN_SILENCE_LEN,
                silence_thresh=SILENCE_THRESH
            )
            if silences_extra:
                cut = start + silences_extra[0][1]
            else:
                cut = search_end_extra
        if cut - start < min_len:
            cut = min(start + min_len, audio_len)
        segment = segment_audio[start:cut]
        segments.append(segment)
        start = cut
    for i, s in enumerate(segments):
         return segments

# %%
# @retry(stop=stop_after_attempt(3),
#        wait=wait_exponential(multiplier=1, min=4, max=10))
# def transcription(audio_file_path, txt_output_dir):
#     """
#     Transcribes a WAV file, saves transcription to .txt,
#     and returns the transcription text.
#     """
#     audio_path = Path(audio_file_path)
#     txt_output_dir = Path(txt_output_dir)
#     txt_output_dir.mkdir(parents=True, exist_ok=True)
#     txt_file_path = txt_output_dir / f"{audio_path.stem}.txt"
#     if txt_file_path.exists():
#         return txt_file_path.read_text(encoding="utf-8").strip()
#     try:
#         prompt = """
#         Please transcribe this Arabic audio accurately.The audio contains Egyptian Arabic dialect speech.

#         Instructions:
#         1. Transcribe exactly what is spoken in Arabic script.
#         2. Do not add any diacritics (tashkeel).
#         3. Include natural speech patterns and colloquialisms.
#         4. If any English text is spoken, map its characters to Arabic(e.g., 'K' -> 'كي').
#         5. Return only the transcribed text, with no additional explanations.
#         """
#         audio_part = {
#             "mime_type": "audio/wav",
#             "data": audio_path.read_bytes()
#         }
#         response = model.generate_content([prompt, audio_part])
#         text = response.text.strip()
#         txt_file_path.write_text(text, encoding="utf-8")
#         return text
#     except Exception as e:
#         print(f"Transcription failed for {audio_path.name}: {e}")
#         return "[transcription_failed]"

# %%
def transcription(audio_file_path):
    audio_path = Path(audio_file_path)
    txt_file_path = audio_path.with_suffix(".txt")
    if txt_file_path.exists():
        return txt_file_path
    try:
        result = whisper_model.transcribe(str(audio_path), language=None)
        text = result['text'].strip()
        txt_file_path.write_text(text, encoding="utf-8")
        return txt_file_path
    except Exception as e:
        print(f"Transcription failed for {audio_path.name}: {e}")
        return txt_file_path

# %%
def get_embedding(segment_audio):
    samples = np.array(segment_audio.get_array_of_samples(), dtype=np.float32)

    if segment_audio.channels > 1:
        samples = samples.reshape(-1, segment_audio.channels).mean(axis=1)

    waveform = torch.tensor(samples).unsqueeze(0)

    audio_input = {
        "waveform": waveform,
        "sample_rate": segment_audio.frame_rate
    }

    emb = embedding_model(audio_input)
    embedding_tensor = torch.tensor(emb.data)
    return embedding_tensor

# %%
def assign_speaker(embedding, speaker_embeddings, threshold=0.65):
    emb_mean = embedding.mean(dim=0)
    sims = {
        spk: torch.nn.functional.cosine_similarity(
            emb_mean.unsqueeze(0),
            ref.unsqueeze(0)
        ).item()
        for spk, ref in speaker_embeddings.items()
    }
    return max(sims, key=sims.get)

# %%
embeddings_file = "speaker_embeddings.pt"
if os.path.exists(embeddings_file):
    speaker_embeddings_db = torch.load(embeddings_file)
    print(" Loaded existing speaker embeddings.")
else:
    speaker_embeddings_db = {}
    print("No existing embeddings found, will create new ones.")
# Out:
#  Loaded existing speaker embeddings.
# C:\Users\laila\AppData\Local\Temp\ipykernel_33100\1787542615.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   speaker_embeddings_db = torch.load(embeddings_file)

# %%
audio_folder = "Audio_folder"
output_folder = "Dataset"
Final_Data = pd.DataFrame(
    columns=["Speaker", "Audio_file", "Transcription"]
)
os.makedirs(output_folder, exist_ok=True)
for file_name in os.listdir(audio_folder):
    if not file_name.endswith(".wav"):
        continue
    print(f"\nProcessing file: {file_name}") 
    podcast_name = Path(file_name).stem
    file_path = os.path.join(audio_folder, file_name)
    podcast_dir = os.path.join(output_folder, podcast_name)
    os.makedirs(podcast_dir, exist_ok=True)
    audio = AudioSegment.from_wav(file_path)
    diarization = pipeline(file_path, num_speakers=2)
    print(f"Diarization done | Number of segments: {len(list(diarization.itertracks(yield_label=True)))}")
    if not speaker_embeddings_db:  
        print("Creating speaker embeddings for first time...")
    speaker_audio = {"host": [], "guest": []}
    for turn, _, speaker in diarization.itertracks(yield_label=True):
        start_ms = int(turn.start*1000)
        end_ms = int(turn.end*1000)
        segment_audio = audio[start_ms:end_ms]
        sub_segments = split_segment(segment_audio)
        if speaker == "SPEAKER_00":
            speaker_audio["host"].extend(sub_segments)
        else:
            speaker_audio["guest"].extend(sub_segments)
    for spk, segments in speaker_audio.items():
        embeddings = []
        for seg in segments:
            emb = get_embedding(seg)
            embeddings.append(emb.mean(dim=0))
        speaker_embeddings_db[spk] = torch.stack(embeddings).mean(dim=0)
    torch.save(speaker_embeddings_db, embeddings_file)
    print(" Embeddings for first podcast initialized and saved")
    speaker_counter = {"host":0, "guest":0}
    pending_segment = {"host": None, "guest": None}
    speaker_turns = {"host": [], "guest": []}
    for turn, _, speaker in diarization.itertracks(yield_label=True):
        if speaker == "SPEAKER_00":
            speaker_turns["host"].append(turn)
    else:
        speaker_turns["guest"].append(turn)
    for spk, turns in speaker_turns.items():
        for turn in speaker_turns[spk]:
            start_ms = int(turn.start*1000)
            end_ms = int(turn.end*1000)
            segment_audio = audio[start_ms:end_ms]
            emb = get_embedding(segment_audio)
            speaker_name = assign_speaker(emb, speaker_embeddings_db)
            if pending_segment[speaker_name] is not None:
                segment_audio = pending_segment[speaker_name] + segment_audio
            pending_segment[speaker_name] = None
            sub_segments = split_segment(segment_audio)
            sub_len = len(sub_segments)
            for i, sub in enumerate(sub_segments):
                if len(sub_segments) == 1 and len(sub) < MIN_LEN :
                    pending_segment[speaker_name] =sub
                    continue
                if i == len(sub_segments) - 1 and len(sub) < MIN_LEN:
                    pending_segment[speaker_name] =sub
                    continue
                speaker_counter[speaker_name] += 1
                audio_file_name = f"{podcast_name}_{speaker_name}_{speaker_counter[speaker_name]:02d}.wav"
                audio_file_path = os.path.join(podcast_dir, audio_file_name)
                sub.export(audio_file_path, format="wav")
                print(f"Segment {speaker_counter[speaker_name]:02d} | Speaker: {speaker_name} | Duration: {len(sub)/1000:.2f}s")
                transcription_file_path = transcription(audio_file_path)
                print(f"Transcription done | File: {audio_file_name} | Transcription path: {transcription_file_path}")  
                Final_Data = pd.concat(
                    [Final_Data, pd.DataFrame([{
                        "Speaker": speaker_name,
                        "Audio_file": audio_file_path,
                        "Transcription": transcription_file_path
                    }])],
                    ignore_index=True
                )
print(f" Finished processing file: {file_name}")
# Out:
# Processing file: برمجة_المنطق_Recursion_والقوائم_في_Prolog.wav
# C:\Users\laila\.conda\envs\pyannote310_env\lib\site-packages\pyannote\audio\models\blocks\pooling.py:104: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\ReduceOps.cpp:1823.)
#   std = sequences.std(dim=-1, correction=1)
# Diarization done | Number of segments: 80
# C:\Users\laila\.conda\envs\pyannote310_env\lib\site-packages\pyannote\audio\utils\reproducibility.py:74: ReproducibilityWarning: TensorFloat-32 (TF32) has been disabled as it might lead to reproducibility issues and lower accuracy.
# It can be re-enabled by calling
#    >>> import torch
#    >>> torch.backends.cuda.matmul.allow_tf32 = True
#    >>> torch.backends.cudnn.allow_tf32 = True
# See https://github.com/pyannote/pyannote-audio/issues/1370 for more details.
#
#   warnings.warn(
#  Embeddings for first podcast initialized and saved
# Segment 01 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_01.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_01.txt
# Segment 02 | Speaker: host | Duration: 7.74s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_02.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_02.txt
# Segment 03 | Speaker: host | Duration: 6.67s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_03.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_03.txt
# Segment 04 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_04.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_04.txt
# Segment 05 | Speaker: host | Duration: 5.28s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_05.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_05.txt
# Segment 06 | Speaker: host | Duration: 5.99s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_06.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_06.txt
# Segment 07 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_07.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_07.txt
# Segment 08 | Speaker: host | Duration: 6.18s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_08.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_08.txt
# Segment 09 | Speaker: host | Duration: 6.44s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_09.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_09.txt
# Segment 10 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_10.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_10.txt
# Segment 11 | Speaker: host | Duration: 9.48s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_11.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_11.txt
# Segment 12 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_12.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_12.txt
# Segment 13 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_13.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_13.txt
# Segment 14 | Speaker: host | Duration: 6.56s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_14.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_14.txt
# Segment 15 | Speaker: host | Duration: 5.16s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_15.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_15.txt
# Segment 16 | Speaker: host | Duration: 5.71s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_16.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_16.txt
# Segment 17 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_17.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_17.txt
# Segment 18 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_18.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_18.txt
# Segment 19 | Speaker: host | Duration: 5.53s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_19.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_19.txt
# Segment 20 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_20.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_20.txt
# Segment 21 | Speaker: host | Duration: 6.07s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_21.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_21.txt
# Segment 22 | Speaker: host | Duration: 5.99s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_22.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_22.txt
# Segment 23 | Speaker: host | Duration: 8.97s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_23.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_23.txt
# Segment 24 | Speaker: host | Duration: 7.22s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_24.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_24.txt
# Segment 25 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_25.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_25.txt
# Segment 26 | Speaker: host | Duration: 7.33s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_26.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_26.txt
# Segment 27 | Speaker: host | Duration: 6.98s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_27.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_27.txt
# Segment 28 | Speaker: host | Duration: 8.16s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_28.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_28.txt
# Segment 29 | Speaker: host | Duration: 5.06s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_29.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_29.txt
# Segment 30 | Speaker: host | Duration: 5.99s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_30.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_30.txt
# Segment 31 | Speaker: host | Duration: 6.45s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_31.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_31.txt
# Segment 32 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_32.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_32.txt
# Segment 33 | Speaker: host | Duration: 5.41s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_33.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_33.txt
# Segment 34 | Speaker: host | Duration: 6.21s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_34.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_34.txt
# Segment 35 | Speaker: host | Duration: 6.38s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_35.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_35.txt
# Segment 36 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_36.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_36.txt
# Segment 37 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_37.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_37.txt
# Segment 38 | Speaker: host | Duration: 7.73s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_38.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_38.txt
# Segment 39 | Speaker: host | Duration: 9.60s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_39.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_39.txt
# Segment 40 | Speaker: host | Duration: 6.18s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_40.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_40.txt
# Segment 41 | Speaker: host | Duration: 5.29s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_41.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_41.txt
# Segment 42 | Speaker: host | Duration: 9.60s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_42.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_42.txt
# Segment 43 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_43.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_43.txt
# Segment 44 | Speaker: host | Duration: 5.53s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_44.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_44.txt
# Segment 45 | Speaker: host | Duration: 9.60s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_45.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_45.txt
# Segment 46 | Speaker: host | Duration: 9.60s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_46.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_46.txt
# Segment 47 | Speaker: host | Duration: 7.59s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_47.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_47.txt
# Segment 48 | Speaker: host | Duration: 5.72s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_48.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_48.txt
# Segment 49 | Speaker: host | Duration: 8.53s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_49.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_49.txt
# Segment 50 | Speaker: host | Duration: 6.09s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_50.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_50.txt
# Segment 51 | Speaker: host | Duration: 5.79s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_51.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_51.txt
# Segment 52 | Speaker: host | Duration: 7.86s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_52.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_52.txt
# Segment 53 | Speaker: host | Duration: 5.25s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_53.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_53.txt
# Segment 54 | Speaker: host | Duration: 7.68s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_54.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_54.txt
# Segment 55 | Speaker: host | Duration: 5.20s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_55.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_55.txt
# Segment 56 | Speaker: host | Duration: 5.79s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_56.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_56.txt
# Segment 57 | Speaker: host | Duration: 9.22s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_57.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_57.txt
# Segment 58 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_58.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_58.txt
# Segment 59 | Speaker: host | Duration: 6.17s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_59.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_59.txt
# Segment 60 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_60.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_60.txt
# Segment 61 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_61.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_61.txt
# Segment 62 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_62.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_62.txt
# Segment 63 | Speaker: host | Duration: 9.60s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_63.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_63.txt
# Segment 64 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_64.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_64.txt
# Segment 65 | Speaker: host | Duration: 8.02s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_65.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_65.txt
# Segment 66 | Speaker: host | Duration: 7.85s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_66.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_66.txt
# Segment 67 | Speaker: host | Duration: 7.86s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_67.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_67.txt
# Segment 68 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_68.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_68.txt
# Segment 69 | Speaker: host | Duration: 9.60s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_69.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_69.txt
# Segment 70 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_70.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_70.txt
# Segment 71 | Speaker: host | Duration: 8.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_71.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_71.txt
# Segment 72 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_72.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_72.txt
# Segment 73 | Speaker: host | Duration: 7.65s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_73.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_73.txt
# Segment 74 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_74.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_74.txt
# Segment 75 | Speaker: host | Duration: 8.25s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_75.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_75.txt
# Segment 76 | Speaker: host | Duration: 6.54s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_76.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_76.txt
# Segment 77 | Speaker: host | Duration: 6.08s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_77.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_77.txt
# Segment 78 | Speaker: host | Duration: 6.04s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_78.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_78.txt
# Segment 79 | Speaker: host | Duration: 5.00s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_79.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_host_79.txt
# Segment 01 | Speaker: guest | Duration: 9.60s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_guest_01.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_guest_01.txt
# Segment 02 | Speaker: guest | Duration: 9.60s
# Transcription done | File: برمجة_المنطق_Recursion_والقوائم_في_Prolog_guest_02.wav | Transcription path: Dataset\برمجة_المنطق_Recursion_والقوائم_في_Prolog\برمجة_المنطق_Recursion_والقوائم_في_Prolog_guest_02.txt
#  Finished processing file: برمجة_المنطق_Recursion_والقوائم_في_Prolog.wav

# %%
csv_file = os.path.join(output_folder, "Dataset.csv")
if os.path.exists(csv_file):
    old_data = pd.read_csv(csv_file)
    Final_Data = pd.concat([old_data, Final_Data], ignore_index=True)

Final_Data.to_csv(csv_file, index=False, encoding="utf-8")
print("Process Done and data saved.")
# Out:
# Process Done and data saved.
